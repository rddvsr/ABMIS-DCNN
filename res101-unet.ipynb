# %%
 pip install -U --pre segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl.metadata (938 bytes)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet==1.0.0->segmentation-models) (0.22.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.26.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.10.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.1)
# Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm

# %%
import cv2
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping,ModelCheckpoint
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import MeanIoU


def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

BACKBONE = 'resnet101'
preprocess_input = sm.get_preprocessing(BACKBONE)

# Define the path to the data directory
data_dir = '/kaggle/input/liverdata/data/'

# Initialize lists to store images and masks
images = []
masks = []

# Loop through the subdirectories
for subdir in os.listdir(data_dir):
    if subdir.startswith('image_'):
        # Load the imaging and segmentation images
        image_path = os.path.join(data_dir, subdir, 'imaging.png')
        mask_path = os.path.join(data_dir, subdir, 'segmentation.png')
        
        # Open the image with OpenCV, equalize its histogram, and convert it to an array
        img = cv2.imread(image_path, cv2.IMREAD_COLOR)
        #img_equalized = cv2.equalizeHist(img)
        img_resized = cv2.resize(img, (256, 256))
        image = img_to_array(img_resized) / 255.0 # normalize pixel values
        images.append(image)
        
        # Open the mask with Pillow, resize it, and convert it to an array
        with Image.open(mask_path) as img:
            img_resized = img.resize((256, 256), Image.LANCZOS)
            mask = img_to_array(img_resized) / 255.0 # normalize pixel values
            #mask = np.expand_dims(mask, axis=-1) # add channel dimension
            masks.append(mask)

# Convert lists to numpy arrays
images = np.array(images)
masks = np.array(masks)

# Display one sample image and its corresponding mask
sample_index = 47 # Change this to display a different sample
sample_image = images[sample_index]
sample_mask = masks[sample_index]
# Plot the image
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(sample_image.squeeze(), cmap='gray')
plt.title('Sample Image')
plt.axis('off')

# Plot the mask
plt.subplot(1, 2, 2)
plt.imshow(sample_mask.squeeze(), cmap='gray')
plt.title('Sample Mask')
plt.axis('off')

plt.show()
# Split the data into train and validation sets
train_images, val_images, train_masks, val_masks = train_test_split(images, masks, test_size=0.2, random_state=42)
# preprocess input
x_train = preprocess_input(train_images)
x_val = preprocess_input(val_images)

# define model
model = sm.Unet(BACKBONE,classes=1, activation='sigmoid', encoder_weights='imagenet')
model.compile(
    'Adam',loss='binary_crossentropy',
    #loss=sm.losses.bce_jaccard_loss,
    metrics=[MeanIoU(num_classes=1),'accuracy']
)
tensorboard_callback = TensorBoard(log_dir='t1_Res101_Unet_logs')
#early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
model_checkpoint_callback = ModelCheckpoint('T1_RES101_Unet_best_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
# fit model
# if you use data generator use model.fit_generator(...) instead of model.fit(...)
# more about `fit_generator` here: https://keras.io/models/sequential/#fit_generator
history=model.fit(
   x=train_images,
   y=train_masks,
   batch_size=16,
   epochs=100,
   validation_data=(val_images, val_masks), callbacks=[tensorboard_callback, model_checkpoint_callback]
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710591321.940429     123 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9199 - loss: 0.2601 - mean_io_u_3: 1.0000
# Epoch 1: val_loss improved from inf to 1.93356, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 239s 1s/step - accuracy: 0.9203 - loss: 0.2589 - mean_io_u_3: 1.0000 - val_accuracy: 0.4963 - val_loss: 1.9336 - val_mean_io_u_3: 1.0000
# Epoch 2/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9789 - loss: 0.0307 - mean_io_u_3: 1.0000
# Epoch 2: val_loss improved from 1.93356 to 0.16046, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9789 - loss: 0.0307 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.1605 - val_mean_io_u_3: 1.0000
# Epoch 3/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9777 - loss: 0.0288 - mean_io_u_3: 1.0000
# Epoch 3: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9777 - loss: 0.0288 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.2448 - val_mean_io_u_3: 1.0000
# Epoch 4/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9783 - loss: 0.0233 - mean_io_u_3: 1.0000
# Epoch 4: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9783 - loss: 0.0233 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.2564 - val_mean_io_u_3: 1.0000
# Epoch 5/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9802 - loss: 0.0151 - mean_io_u_3: 1.0000
# Epoch 5: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9802 - loss: 0.0151 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.2740 - val_mean_io_u_3: 1.0000
# Epoch 6/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9824 - loss: 0.0100 - mean_io_u_3: 1.0000
# Epoch 6: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9824 - loss: 0.0100 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.2759 - val_mean_io_u_3: 1.0000
# Epoch 7/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9823 - loss: 0.0080 - mean_io_u_3: 1.0000
# Epoch 7: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9823 - loss: 0.0080 - mean_io_u_3: 1.0000 - val_accuracy: 0.9481 - val_loss: 0.2886 - val_mean_io_u_3: 1.0000
# Epoch 8/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9823 - loss: 0.0083 - mean_io_u_3: 1.0000
# Epoch 8: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9823 - loss: 0.0083 - mean_io_u_3: 1.0000 - val_accuracy: 0.8676 - val_loss: 0.3794 - val_mean_io_u_3: 1.0000
# Epoch 9/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9816 - loss: 0.0149 - mean_io_u_3: 1.0000
# Epoch 9: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9816 - loss: 0.0148 - mean_io_u_3: 1.0000 - val_accuracy: 0.9483 - val_loss: 0.2706 - val_mean_io_u_3: 1.0000
# Epoch 10/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9800 - loss: 0.0179 - mean_io_u_3: 1.0000
# Epoch 10: val_loss did not improve from 0.16046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9800 - loss: 0.0178 - mean_io_u_3: 1.0000 - val_accuracy: 0.9471 - val_loss: 0.2119 - val_mean_io_u_3: 1.0000
# Epoch 11/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9821 - loss: 0.0098 - mean_io_u_3: 1.0000
# Epoch 11: val_loss improved from 0.16046 to 0.04477, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9821 - loss: 0.0098 - mean_io_u_3: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.0448 - val_mean_io_u_3: 1.0000
# Epoch 12/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9821 - loss: 0.0076 - mean_io_u_3: 1.0000
# Epoch 12: val_loss improved from 0.04477 to 0.02576, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.9821 - loss: 0.0076 - mean_io_u_3: 1.0000 - val_accuracy: 0.9770 - val_loss: 0.0258 - val_mean_io_u_3: 1.0000
# Epoch 13/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9821 - loss: 0.0061 - mean_io_u_3: 1.0000
# Epoch 13: val_loss improved from 0.02576 to 0.00889, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9821 - loss: 0.0061 - mean_io_u_3: 1.0000 - val_accuracy: 0.9818 - val_loss: 0.0089 - val_mean_io_u_3: 1.0000
# Epoch 14/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9832 - loss: 0.0057 - mean_io_u_3: 1.0000
# Epoch 14: val_loss improved from 0.00889 to 0.00636, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 303ms/step - accuracy: 0.9831 - loss: 0.0057 - mean_io_u_3: 1.0000 - val_accuracy: 0.9825 - val_loss: 0.0064 - val_mean_io_u_3: 1.0000
# Epoch 15/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9818 - loss: 0.0054 - mean_io_u_3: 1.0000
# Epoch 15: val_loss improved from 0.00636 to 0.00574, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9818 - loss: 0.0054 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0057 - val_mean_io_u_3: 1.0000
# Epoch 16/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9828 - loss: 0.0050 - mean_io_u_3: 1.0000
# Epoch 16: val_loss improved from 0.00574 to 0.00557, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9828 - loss: 0.0050 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0056 - val_mean_io_u_3: 1.0000
# Epoch 17/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9832 - loss: 0.0047 - mean_io_u_3: 1.0000
# Epoch 17: val_loss improved from 0.00557 to 0.00541, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 301ms/step - accuracy: 0.9832 - loss: 0.0048 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0054 - val_mean_io_u_3: 1.0000
# Epoch 18/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9832 - loss: 0.0047 - mean_io_u_3: 1.0000
# Epoch 18: val_loss improved from 0.00541 to 0.00521, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - accuracy: 0.9832 - loss: 0.0047 - mean_io_u_3: 1.0000 - val_accuracy: 0.9828 - val_loss: 0.0052 - val_mean_io_u_3: 1.0000
# Epoch 19/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9829 - loss: 0.0045 - mean_io_u_3: 1.0000
# Epoch 19: val_loss did not improve from 0.00521
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9829 - loss: 0.0045 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0054 - val_mean_io_u_3: 1.0000
# Epoch 20/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9815 - loss: 0.0042 - mean_io_u_3: 1.0000
# Epoch 20: val_loss improved from 0.00521 to 0.00486, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9815 - loss: 0.0042 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 21/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9823 - loss: 0.0039 - mean_io_u_3: 1.0000
# Epoch 21: val_loss improved from 0.00486 to 0.00476, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9823 - loss: 0.0039 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 22/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9836 - loss: 0.0037 - mean_io_u_3: 1.0000
# Epoch 22: val_loss improved from 0.00476 to 0.00470, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 301ms/step - accuracy: 0.9836 - loss: 0.0037 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 23/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9829 - loss: 0.0040 - mean_io_u_3: 1.0000
# Epoch 23: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9829 - loss: 0.0040 - mean_io_u_3: 1.0000 - val_accuracy: 0.8831 - val_loss: 0.5747 - val_mean_io_u_3: 1.0000
# Epoch 24/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9756 - loss: 0.0293 - mean_io_u_3: 1.0000
# Epoch 24: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9757 - loss: 0.0292 - mean_io_u_3: 1.0000 - val_accuracy: 0.9669 - val_loss: 0.2524 - val_mean_io_u_3: 1.0000
# Epoch 25/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9821 - loss: 0.0095 - mean_io_u_3: 1.0000
# Epoch 25: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9820 - loss: 0.0094 - mean_io_u_3: 1.0000 - val_accuracy: 0.9636 - val_loss: 0.1741 - val_mean_io_u_3: 1.0000
# Epoch 26/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9815 - loss: 0.0075 - mean_io_u_3: 1.0000
# Epoch 26: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9815 - loss: 0.0075 - mean_io_u_3: 1.0000 - val_accuracy: 0.9812 - val_loss: 0.0189 - val_mean_io_u_3: 1.0000
# Epoch 27/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9809 - loss: 0.0071 - mean_io_u_3: 1.0000
# Epoch 27: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 272ms/step - accuracy: 0.9809 - loss: 0.0070 - mean_io_u_3: 1.0000 - val_accuracy: 0.9825 - val_loss: 0.0066 - val_mean_io_u_3: 1.0000
# Epoch 28/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9834 - loss: 0.0052 - mean_io_u_3: 1.0000
# Epoch 28: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9834 - loss: 0.0052 - mean_io_u_3: 1.0000 - val_accuracy: 0.9826 - val_loss: 0.0059 - val_mean_io_u_3: 1.0000
# Epoch 29/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9830 - loss: 0.0049 - mean_io_u_3: 1.0000
# Epoch 29: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9830 - loss: 0.0049 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0054 - val_mean_io_u_3: 1.0000
# Epoch 30/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9831 - loss: 0.0044 - mean_io_u_3: 1.0000
# Epoch 30: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 272ms/step - accuracy: 0.9831 - loss: 0.0044 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0056 - val_mean_io_u_3: 1.0000
# Epoch 31/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000
# Epoch 31: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000 - val_accuracy: 0.9828 - val_loss: 0.0052 - val_mean_io_u_3: 1.0000
# Epoch 32/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9836 - loss: 0.0039 - mean_io_u_3: 1.0000
# Epoch 32: val_loss did not improve from 0.00470
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9836 - loss: 0.0039 - mean_io_u_3: 1.0000 - val_accuracy: 0.9828 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 33/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9824 - loss: 0.0038 - mean_io_u_3: 1.0000
# Epoch 33: val_loss improved from 0.00470 to 0.00467, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 301ms/step - accuracy: 0.9824 - loss: 0.0038 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 34/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9835 - loss: 0.0037 - mean_io_u_3: 1.0000
# Epoch 34: val_loss improved from 0.00467 to 0.00462, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9834 - loss: 0.0037 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 35/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9836 - loss: 0.0035 - mean_io_u_3: 1.0000
# Epoch 35: val_loss did not improve from 0.00462
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 273ms/step - accuracy: 0.9836 - loss: 0.0035 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 36/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9839 - loss: 0.0037 - mean_io_u_3: 1.0000
# Epoch 36: val_loss did not improve from 0.00462
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9839 - loss: 0.0037 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 37/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9830 - loss: 0.0038 - mean_io_u_3: 1.0000
# Epoch 37: val_loss improved from 0.00462 to 0.00461, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9830 - loss: 0.0038 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 38/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9829 - loss: 0.0035 - mean_io_u_3: 1.0000
# Epoch 38: val_loss improved from 0.00461 to 0.00452, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 302ms/step - accuracy: 0.9829 - loss: 0.0035 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 39/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9824 - loss: 0.0035 - mean_io_u_3: 1.0000
# Epoch 39: val_loss did not improve from 0.00452
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9825 - loss: 0.0035 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 40/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9826 - loss: 0.0034 - mean_io_u_3: 1.0000
# Epoch 40: val_loss did not improve from 0.00452
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9827 - loss: 0.0034 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 41/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9833 - loss: 0.0034 - mean_io_u_3: 1.0000
# Epoch 41: val_loss improved from 0.00452 to 0.00442, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9833 - loss: 0.0034 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 42/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9844 - loss: 0.0033 - mean_io_u_3: 1.0000
# Epoch 42: val_loss improved from 0.00442 to 0.00434, saving model to T1_RES101_Unet_best_model.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.9844 - loss: 0.0033 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0043 - val_mean_io_u_3: 1.0000
# Epoch 43/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9826 - loss: 0.0032 - mean_io_u_3: 1.0000
# Epoch 43: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 272ms/step - accuracy: 0.9826 - loss: 0.0032 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 44/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9840 - loss: 0.0032 - mean_io_u_3: 1.0000
# Epoch 44: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 272ms/step - accuracy: 0.9840 - loss: 0.0032 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 45/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9833 - loss: 0.0049 - mean_io_u_3: 1.0000
# Epoch 45: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 271ms/step - accuracy: 0.9833 - loss: 0.0049 - mean_io_u_3: 1.0000 - val_accuracy: 0.8816 - val_loss: 0.9108 - val_mean_io_u_3: 1.0000
# Epoch 46/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9792 - loss: 0.0168 - mean_io_u_3: 1.0000
# Epoch 46: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9792 - loss: 0.0168 - mean_io_u_3: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.2567 - val_mean_io_u_3: 1.0000
# Epoch 47/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9818 - loss: 0.0076 - mean_io_u_3: 1.0000
# Epoch 47: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 272ms/step - accuracy: 0.9818 - loss: 0.0076 - mean_io_u_3: 1.0000 - val_accuracy: 0.9803 - val_loss: 0.0288 - val_mean_io_u_3: 1.0000
# Epoch 48/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9828 - loss: 0.0053 - mean_io_u_3: 1.0000
# Epoch 48: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9828 - loss: 0.0053 - mean_io_u_3: 1.0000 - val_accuracy: 0.9825 - val_loss: 0.0065 - val_mean_io_u_3: 1.0000
# Epoch 49/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9820 - loss: 0.0045 - mean_io_u_3: 1.0000
# Epoch 49: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9820 - loss: 0.0045 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0053 - val_mean_io_u_3: 1.0000
# Epoch 50/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000
# Epoch 50: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000 - val_accuracy: 0.9828 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 51/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9816 - loss: 0.0039 - mean_io_u_3: 1.0000
# Epoch 51: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9816 - loss: 0.0039 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 52/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9829 - loss: 0.0036 - mean_io_u_3: 1.0000
# Epoch 52: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9829 - loss: 0.0036 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 53/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9824 - loss: 0.0033 - mean_io_u_3: 1.0000
# Epoch 53: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9824 - loss: 0.0033 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 54/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9827 - loss: 0.0034 - mean_io_u_3: 1.0000
# Epoch 54: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9827 - loss: 0.0034 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 55/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9838 - loss: 0.0033 - mean_io_u_3: 1.0000
# Epoch 55: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9838 - loss: 0.0033 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 56/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9820 - loss: 0.0031 - mean_io_u_3: 1.0000
# Epoch 56: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9820 - loss: 0.0031 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 57/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9838 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 57: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9838 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 58/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9823 - loss: 0.0032 - mean_io_u_3: 1.0000
# Epoch 58: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9823 - loss: 0.0032 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 59/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9830 - loss: 0.0033 - mean_io_u_3: 1.0000
# Epoch 59: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9830 - loss: 0.0033 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 60/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9823 - loss: 0.0032 - mean_io_u_3: 1.0000
# Epoch 60: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9823 - loss: 0.0032 - mean_io_u_3: 1.0000 - val_accuracy: 0.9553 - val_loss: 0.1765 - val_mean_io_u_3: 1.0000
# Epoch 61/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9823 - loss: 0.0092 - mean_io_u_3: 1.0000
# Epoch 61: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9823 - loss: 0.0092 - mean_io_u_3: 1.0000 - val_accuracy: 0.9813 - val_loss: 0.0139 - val_mean_io_u_3: 1.0000
# Epoch 62/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9836 - loss: 0.0050 - mean_io_u_3: 1.0000
# Epoch 62: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9836 - loss: 0.0050 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0054 - val_mean_io_u_3: 1.0000
# Epoch 63/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9826 - loss: 0.0039 - mean_io_u_3: 1.0000
# Epoch 63: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 271ms/step - accuracy: 0.9826 - loss: 0.0039 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 64/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9828 - loss: 0.0035 - mean_io_u_3: 1.0000
# Epoch 64: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9828 - loss: 0.0035 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 65/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9825 - loss: 0.0035 - mean_io_u_3: 1.0000
# Epoch 65: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9825 - loss: 0.0035 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 66/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9827 - loss: 0.0033 - mean_io_u_3: 1.0000
# Epoch 66: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9827 - loss: 0.0033 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 67/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9836 - loss: 0.0032 - mean_io_u_3: 1.0000
# Epoch 67: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9836 - loss: 0.0032 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 68/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9826 - loss: 0.0031 - mean_io_u_3: 1.0000
# Epoch 68: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9826 - loss: 0.0031 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 69/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9834 - loss: 0.0029 - mean_io_u_3: 1.0000
# Epoch 69: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9834 - loss: 0.0029 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 70/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9819 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 70: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9820 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 71/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9826 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 71: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9826 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 72/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9831 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 72: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9831 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 73/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9829 - loss: 0.0031 - mean_io_u_3: 1.0000
# Epoch 73: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9829 - loss: 0.0031 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 74/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9823 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 74: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9823 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 75/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9827 - loss: 0.0030 - mean_io_u_3: 1.0000
# Epoch 75: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9827 - loss: 0.0030 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 76/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9823 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 76: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9823 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 77/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9834 - loss: 0.0029 - mean_io_u_3: 1.0000
# Epoch 77: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9834 - loss: 0.0029 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 78/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9829 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 78: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9829 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0047 - val_mean_io_u_3: 1.0000
# Epoch 79/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9831 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 79: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9831 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 80/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9824 - loss: 0.0029 - mean_io_u_3: 1.0000
# Epoch 80: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9824 - loss: 0.0029 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 81/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9822 - loss: 0.0026 - mean_io_u_3: 1.0000
# Epoch 81: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9822 - loss: 0.0026 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 82/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9820 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 82: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 269ms/step - accuracy: 0.9821 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0046 - val_mean_io_u_3: 1.0000
# Epoch 83/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9838 - loss: 0.0026 - mean_io_u_3: 1.0000
# Epoch 83: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9838 - loss: 0.0026 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 84/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9828 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 84: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9828 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 85/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9832 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 85: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9832 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0049 - val_mean_io_u_3: 1.0000
# Epoch 86/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9824 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 86: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9824 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 87/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9829 - loss: 0.0027 - mean_io_u_3: 1.0000
# Epoch 87: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9829 - loss: 0.0027 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 88/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9830 - loss: 0.0027 - mean_io_u_3: 1.0000
# Epoch 88: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9830 - loss: 0.0027 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 89/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9824 - loss: 0.0028 - mean_io_u_3: 1.0000
# Epoch 89: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9824 - loss: 0.0028 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 90/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9843 - loss: 0.0026 - mean_io_u_3: 1.0000
# Epoch 90: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9843 - loss: 0.0026 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 91/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9830 - loss: 0.0025 - mean_io_u_3: 1.0000
# Epoch 91: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9830 - loss: 0.0025 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 92/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9828 - loss: 0.0026 - mean_io_u_3: 1.0000
# Epoch 92: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9828 - loss: 0.0026 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0044 - val_mean_io_u_3: 1.0000
# Epoch 93/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9838 - loss: 0.0026 - mean_io_u_3: 1.0000
# Epoch 93: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9838 - loss: 0.0026 - mean_io_u_3: 1.0000 - val_accuracy: 0.9830 - val_loss: 0.0045 - val_mean_io_u_3: 1.0000
# Epoch 94/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9829 - loss: 0.0027 - mean_io_u_3: 1.0000
# Epoch 94: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9829 - loss: 0.0027 - mean_io_u_3: 1.0000 - val_accuracy: 0.9498 - val_loss: 1.1054 - val_mean_io_u_3: 1.0000
# Epoch 95/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9773 - loss: 0.0294 - mean_io_u_3: 1.0000
# Epoch 95: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9773 - loss: 0.0293 - mean_io_u_3: 1.0000 - val_accuracy: 0.9490 - val_loss: 0.3495 - val_mean_io_u_3: 1.0000
# Epoch 96/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9822 - loss: 0.0079 - mean_io_u_3: 1.0000
# Epoch 96: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9822 - loss: 0.0079 - mean_io_u_3: 1.0000 - val_accuracy: 0.9755 - val_loss: 0.0722 - val_mean_io_u_3: 1.0000
# Epoch 97/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9814 - loss: 0.0099 - mean_io_u_3: 1.0000
# Epoch 97: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9814 - loss: 0.0099 - mean_io_u_3: 1.0000 - val_accuracy: 0.9824 - val_loss: 0.0068 - val_mean_io_u_3: 1.0000
# Epoch 98/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9831 - loss: 0.0049 - mean_io_u_3: 1.0000
# Epoch 98: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9831 - loss: 0.0049 - mean_io_u_3: 1.0000 - val_accuracy: 0.9827 - val_loss: 0.0056 - val_mean_io_u_3: 1.0000
# Epoch 99/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000
# Epoch 99: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 269ms/step - accuracy: 0.9831 - loss: 0.0042 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000
# Epoch 100/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9825 - loss: 0.0037 - mean_io_u_3: 1.0000
# Epoch 100: val_loss did not improve from 0.00434
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.9825 - loss: 0.0037 - mean_io_u_3: 1.0000 - val_accuracy: 0.9829 - val_loss: 0.0048 - val_mean_io_u_3: 1.0000

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.show()

# %%
import cv2
import numpy as np
import segmentation_models as sm
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Load the pre-trained model
BACKBONE = 'resnet101'
preprocess_input = sm.get_preprocessing(BACKBONE)

# Assuming you have already defined your model architecture as 'model'
# For example, if you're using a Unet model with a ResNet34 backbone
model = sm.Unet(BACKBONE, encoder_weights='imagenet')
model.load_weights('/kaggle/working/T1_RES101_Unet_best_model.keras')
# Define the preprocessing function
def preprocess_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)
    img_resized = cv2.resize(img, (256, 256))
    image = img_to_array(img_resized) / 255.0
    return image

# Preprocess the test image
test_image_path = '/kaggle/input/liverdata/data/image_177/imaging.png'
test_image = preprocess_image(test_image_path)

# Ensure the image has the correct shape and add the batch dimension
test_image = np.expand_dims(test_image, axis=0) # Now the shape should be (1, 512, 512, 3)

# Perform inference
predictions = model.predict(test_image)

# Post-process the predictions if necessary
# For binary segmentation, you might want to apply a threshold
predictions = (predictions > 0.5).astype(np.uint8)

# Visualize the results
# Assuming you have the corresponding mask for the test image
test_mask_path = '/kaggle/input/liverdata/data/image_177/segmentation.png'
test_mask = cv2.imread(test_mask_path, cv2.IMREAD_GRAYSCALE)
test_mask = cv2.resize(test_mask, (256, 256)) / 255.0

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Original image
axes[0].imshow(test_image[0])
axes[0].set_title('Original Image')

# Ground truth mask
axes[1].imshow(test_mask, cmap='gray')
axes[1].set_title('Ground Truth Mask')

# Predicted mask
axes[2].imshow(predictions[0], cmap='gray')
axes[2].set_title('Predicted Mask')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
